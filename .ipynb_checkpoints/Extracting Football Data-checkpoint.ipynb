# %%
import pandas as pd
url = "https://www.football-data.co.uk/mmz4281/2324/E0.csv"
pd.read_csv(url)
# Out:
#    Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0   E0  11/08/2023  20:00         Burnley       Man City     0     3   A
# 1   E0  12/08/2023  12:30         Arsenal  Nott'm Forest     2     1   H
# 2   E0  12/08/2023  15:00     Bournemouth       West Ham     1     1   D
# 3   E0  12/08/2023  15:00        Brighton          Luton     4     1   H
# 4   E0  12/08/2023  15:00         Everton         Fulham     0     1   A
# ..  ..         ...    ...             ...            ...   ...   ...  ..
# 75  E0  07/10/2023  17:30  Crystal Palace  Nott'm Forest     0     0   D
# 76  E0  08/10/2023  14:00        Brighton      Liverpool     2     2   D
# 77  E0  08/10/2023  14:00        West Ham      Newcastle     2     2   D
# 78  E0  08/10/2023  14:00          Wolves    Aston Villa     1     1   D
# 79  E0  08/10/2023  16:30         Arsenal       Man City     1     0   H
#
#     HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...

# %%
#Create a variable and assign the data
# Show the data to the user using variable
url = "https://www.football-data.co.uk/mmz4281/2324/E0.csv"
pd.read_csv(url)
df_premier23 = pd.read_csv(url)
df_premier23
# Out:
#    Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0   E0  11/08/2023  20:00         Burnley       Man City     0     3   A
# 1   E0  12/08/2023  12:30         Arsenal  Nott'm Forest     2     1   H
# 2   E0  12/08/2023  15:00     Bournemouth       West Ham     1     1   D
# 3   E0  12/08/2023  15:00        Brighton          Luton     4     1   H
# 4   E0  12/08/2023  15:00         Everton         Fulham     0     1   A
# ..  ..         ...    ...             ...            ...   ...   ...  ..
# 75  E0  07/10/2023  17:30  Crystal Palace  Nott'm Forest     0     0   D
# 76  E0  08/10/2023  14:00        Brighton      Liverpool     2     2   D
# 77  E0  08/10/2023  14:00        West Ham      Newcastle     2     2   D
# 78  E0  08/10/2023  14:00          Wolves    Aston Villa     1     1   D
# 79  E0  08/10/2023  16:30         Arsenal       Man City     1     0   H
#
#     HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...

# %%
# Reaname column headings
df_premier23.rename(columns={'FTHG':'home_goals',
                            'FTAG':'away_goals'}, inplace=True)

# Show data frame
df_premier23
# Out:
#    Div        Date   Time        HomeTeam       AwayTeam  home_goals  \
# 0   E0  11/08/2023  20:00         Burnley       Man City           0
# 1   E0  12/08/2023  12:30         Arsenal  Nott'm Forest           2
# 2   E0  12/08/2023  15:00     Bournemouth       West Ham           1
# 3   E0  12/08/2023  15:00        Brighton          Luton           4
# 4   E0  12/08/2023  15:00         Everton         Fulham           0
# ..  ..         ...    ...             ...            ...         ...
# 75  E0  07/10/2023  17:30  Crystal Palace  Nott'm Forest           0
# 76  E0  08/10/2023  14:00        Brighton      Liverpool           2
# 77  E0  08/10/2023  14:00        West Ham      Newcastle           2
# 78  E0  08/10/2023  14:00          Wolves    Aston Villa           1
# 79  E0  08/10/2023  16:30         Arsenal       Man City           1
#
#     away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  \
# ...
